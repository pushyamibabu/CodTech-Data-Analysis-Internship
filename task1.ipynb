# %%
import pandas as pd

df = pd.read_excel("normalized_uber_data_enhanced (1).xlsx")
df.head()
# Out:
#         Date      Time  Hour  Time_Slot Day_of_Week  TimeID
# 0 2024-03-23  12:29:38    12    Morning    Saturday       1
# 1 2024-11-29  18:01:39    18  Afternoon      Friday       2
# 2 2024-08-23  08:56:10     8    Morning      Friday       3
# 3 2024-10-21  17:17:25    17  Afternoon      Monday       4
# 4 2024-09-16  22:08:00    22    Evening      Monday       5

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Hour', 'Time_Slot', 'Day_of_Week', 'TimeID'], dtype='object')

# %%
df = df.dropna()

# %%
df.describe()
# Out:
#                                 Date           Hour         TimeID
# count                         149532  149532.000000  149532.000000
# mean   2024-06-30 16:37:42.097744896      14.032608   74766.500000
# min              2024-01-01 00:00:00       0.000000       1.000000
# 25%              2024-03-31 00:00:00      10.000000   37383.750000
# 50%              2024-07-01 00:00:00      15.000000   74766.500000
# 75%              2024-09-30 00:00:00      18.000000  112149.250000
# max              2024-12-30 00:00:00      23.000000  149532.000000
# std                              NaN       5.418670   43166.314564

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(12, 8))  # makes graph bigger
plt.xticks(rotation=45)   # rotates labels
plt.tight_layout()        # fixes overlapping
plt.show()

# %% [markdown]
# INSIGHTS:
#
# 1. The dataset contains ride-related information such as date, hour, and time ID.
# 2. The distribution of rides varies across different hours of the day.
# 3. The data shows patterns that can help analyze peak ride times.
